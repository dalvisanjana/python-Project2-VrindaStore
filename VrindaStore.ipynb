# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\sanja\Data analytics\Vrinda-Store.csv")

# %%
data
# Out:
#        index             Order ID  Cust ID Gender  Age Age Group       Date  \
# 0          1  171-1029312-3038738  1029312  Women   44     Adult  12/4/2022
# 1          2  405-2183842-2225946  2183842  Women   29  Teenager  12/4/2022
# 2          3  171-1641533-8921966  1641533  Women   67    Senior  12/4/2022
# 3          4  404-7490807-6300351  7490807  Women   20  Teenager  12/4/2022
# 4          5  403-9293516-4577154  9293516  Women   62    Senior  12/4/2022
# ...      ...                  ...      ...    ...  ...       ...        ...
# 31042  31043  405-4724097-1016369  4724097    Men   60    Senior   1/6/2022
# 31043  31044  405-4724097-1016369  4724097    Men   34     Adult   1/6/2022
# 31044  31045  408-3572295-5992330  3572295    Men   29  Teenager   1/6/2022
# 31045  31046  405-1423498-9705162  1423498    Men   46     Adult   1/6/2022
# 31046  31047  408-4694875-8249153  4694875    Men   36     Adult   1/6/2022
#
# ...

# %%
# How to Analyze DataFrames

#.head() - It shows the first N rows in the data (by default N=5)

data.head()
# Out:
#    index             Order ID  Cust ID Gender  Age Age Group       Date Month  \
# 0      1  171-1029312-3038738  1029312  Women   44     Adult  12/4/2022   Dec
# 1      2  405-2183842-2225946  2183842  Women   29  Teenager  12/4/2022   Dec
# 2      3  171-1641533-8921966  1641533  Women   67    Senior  12/4/2022   Dec
# 3      4  404-7490807-6300351  7490807  Women   20  Teenager  12/4/2022   Dec
# 4      5  403-9293516-4577154  9293516  Women   62    Senior  12/4/2022   Dec
#
#       Status Channel   ... Category Size Qty  currency Amount  ship-city  \
# 0  Delivered   Myntra  ...    kurta  XXL   1       INR    376     MOHALI
# 1  Delivered     Ajio  ...      Set    L   1       INR   1449   GURUGRAM
# 2  Delivered   Myntra  ...      Set    S   1       INR    453    KOLKATA
# 3  Delivered   Amazon  ...      Set    M   1       INR    729  THANJAVUR
# 4  Delivered   Myntra  ...    kurta  XXL   1       INR    544   GURUGRAM
#
#     ship-state ship-postal-code  ship-country B2B
# ...

# %%
# .shape - it shows the total no of columns of the dataframe
data.shape
# Out:
# (31047, 21)

# %%
# .index - this attribute provide the index of the dataframe
data.index
# Out:
# RangeIndex(start=0, stop=31047, step=1)

# %%
#.columns - it shows the name of each column
data.columns
# Out:
# Index(['index', 'Order ID', 'Cust ID', 'Gender', 'Age', 'Age Group', 'Date',
#        'Month', 'Status', 'Channel ', 'SKU', 'Category', 'Size', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B'],
#       dtype='object')

# %%
# .dtypes - it shows the datatype of each column
data.dtypes
# Out:
# index                 int64
# Order ID             object
# Cust ID               int64
# Gender               object
# Age                   int64
# Age Group            object
# Date                 object
# Month                object
# Status               object
# Channel              object
# SKU                  object
# Category             object
# Size                 object
# Qty                   int64
# currency             object
# Amount                int64
# ship-city            object
# ship-state           object
# ship-postal-code      int64
# ship-country         object
# B2B                 float64
# dtype: object

# %%
#unique() - in a column, it shows the unique value.it can be applied on a single column only not on the whole dataframe

data['Status'].unique()
# Out:
# array(['Delivered', 'Refunded', 'Cancelled', 'Returned'], dtype=object)

# %%
#.nunique() - it shows the total no. of unique values in each column it can be applied on a single column as well as on whole dataframe
data.nunique()
# Out:
# index               31047
# Order ID            28471
# Cust ID             28437
# Gender                  2
# Age                    61
# Age Group               3
# Date                   36
# Month                  12
# Status                  4
# Channel                 7
# SKU                  5287
# Category                8
# Size                   11
# Qty                     5
# currency                1
# Amount                769
# ship-city            2603
# ship-state             50
# ship-postal-code     4958
# ship-country            1
# B2B                     1
# dtype: int64

# %% [raw]
# count - it shows the total no. of non null values in each column. it can be applied on a single column as well as on whole datafra,e
# data.count()

# %%
data['Status'].value_counts()
# Out:
# Status
# Delivered    28641
# Returned      1045
# Cancelled      844
# Refunded       517
# Name: count, dtype: int64

# %%
#info - it shows the basic informaton about data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31047 entries, 0 to 31046
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             31047 non-null  int64
#  1   Order ID          31047 non-null  object
#  2   Cust ID           31047 non-null  int64
#  3   Gender            31047 non-null  object
#  4   Age               31047 non-null  int64
#  5   Age Group         31047 non-null  object
#  6   Date              31047 non-null  object
#  7   Month             31047 non-null  object
#  8   Status            31047 non-null  object
#  9   Channel           31047 non-null  object
#  10  SKU               31047 non-null  object
#  11  Category          31047 non-null  object
#  12  Size              31047 non-null  object
#  13  Qty               31047 non-null  int64
#  14  currency          31047 non-null  object
#  15  Amount            31047 non-null  int64
# ...

# %% [markdown]
# Q1 Find all the unique "Status" in the data

# %%
data.head(2)
# Out:
#    index             Order ID  Cust ID Gender  Age Age Group       Date Month  \
# 0      1  171-1029312-3038738  1029312  Women   44     Adult  12/4/2022   Dec
# 1      2  405-2183842-2225946  2183842  Women   29  Teenager  12/4/2022   Dec
#
#       Status Channel   ... Category Size Qty  currency Amount  ship-city  \
# 0  Delivered   Myntra  ...    kurta  XXL   1       INR    376     MOHALI
# 1  Delivered     Ajio  ...      Set    L   1       INR   1449   GURUGRAM
#
#   ship-state ship-postal-code  ship-country B2B
# 0     PUNJAB           140301            IN NaN
# 1    HARYANA           122002            IN NaN
#
# [2 rows x 21 columns]

# %%
data.nunique()
# Out:
# index               31047
# Order ID            28471
# Cust ID             28437
# Gender                  2
# Age                    61
# Age Group               3
# Date                   36
# Month                  12
# Status                  4
# Channel                 7
# SKU                  5287
# Category                8
# Size                   11
# Qty                     5
# currency                1
# Amount                769
# ship-city            2603
# ship-state             50
# ship-postal-code     4958
# ship-country            1
# B2B                     1
# dtype: int64

# %%
data["Status"].nunique()
# Out:
# 4

# %%
data["Status"].unique()
# Out:
# array(['Delivered', 'Refunded', 'Cancelled', 'Returned'], dtype=object)

# %%
Q2 Find the number of items when the "items is delivered"

# %%
data.head(2)
# Out:
#    index             Order ID  Cust ID Gender  Age Age Group       Date Month  \
# 0      1  171-1029312-3038738  1029312  Women   44     Adult  12/4/2022   Dec
# 1      2  405-2183842-2225946  2183842  Women   29  Teenager  12/4/2022   Dec
#
#       Status Channel   ... Category Size Qty  currency Amount  ship-city  \
# 0  Delivered   Myntra  ...    kurta  XXL   1       INR    376     MOHALI
# 1  Delivered     Ajio  ...      Set    L   1       INR   1449   GURUGRAM
#
#   ship-state ship-postal-code  ship-country B2B
# 0     PUNJAB           140301            IN NaN
# 1    HARYANA           122002            IN NaN
#
# [2 rows x 21 columns]

# %%
# 1 value_counts()
data.Status.value_counts()
# Out:
# Status
# Delivered    28641
# Returned      1045
# Cancelled      844
# Refunded       517
# Name: count, dtype: int64

# %%
# 2 Filetering
data[data.Status== 'clear']
# Out:
# Empty DataFrame
# Columns: [index, Order ID, Cust ID, Gender, Age, Age Group, Date, Month, Status, Channel , SKU, Category, Size, Qty, currency, Amount, ship-city, ship-state, ship-postal-code, ship-country, B2B]
# Index: []
#
# [0 rows x 21 columns]

# %%
#group by
data.groupby('Status').get_group('Delivered')
# Out:
#        index             Order ID  Cust ID Gender  Age Age Group       Date  \
# 0          1  171-1029312-3038738  1029312  Women   44     Adult  12/4/2022
# 1          2  405-2183842-2225946  2183842  Women   29  Teenager  12/4/2022
# 2          3  171-1641533-8921966  1641533  Women   67    Senior  12/4/2022
# 3          4  404-7490807-6300351  7490807  Women   20  Teenager  12/4/2022
# 4          5  403-9293516-4577154  9293516  Women   62    Senior  12/4/2022
# ...      ...                  ...      ...    ...  ...       ...        ...
# 31042  31043  405-4724097-1016369  4724097    Men   60    Senior   1/6/2022
# 31043  31044  405-4724097-1016369  4724097    Men   34     Adult   1/6/2022
# 31044  31045  408-3572295-5992330  3572295    Men   29  Teenager   1/6/2022
# 31045  31046  405-1423498-9705162  1423498    Men   46     Adult   1/6/2022
# 31046  31047  408-4694875-8249153  4694875    Men   36     Adult   1/6/2022
#
# ...

# %% [markdown]
# Q3 Find the number of times when the "Category"

# %%
data.head(2)
# Out:
#    index             Order ID  Cust ID Gender  Age Age Group       Date Month  \
# 0      1  171-1029312-3038738  1029312  Women   44     Adult  12/4/2022   Dec
# 1      2  405-2183842-2225946  2183842  Women   29  Teenager  12/4/2022   Dec
#
#       Status Channel   ... Category Size Qty  currency Amount  ship-city  \
# 0  Delivered   Myntra  ...    kurta  XXL   1       INR    376     MOHALI
# 1  Delivered     Ajio  ...      Set    L   1       INR   1449   GURUGRAM
#
#   ship-state ship-postal-code  ship-country B2B
# 0     PUNJAB           140301            IN NaN
# 1    HARYANA           122002            IN NaN
#
# [2 rows x 21 columns]

# %%
#data[data['ship-state']==4]
data.Category.value_counts()
# Out:
# Category
# Set              12391
# kurta            10446
# Western Dress     4066
# Top               2193
# Saree             1380
# Ethnic Dress       264
# Blouse             229
# Bottom              78
# Name: count, dtype: int64

# %% [markdown]
# Q4 Find out all the Null Values in the data

# %%
data.isnull().sum()
# Out:
# index                   0
# Order ID                0
# Cust ID                 0
# Gender                  0
# Age                     0
# Age Group               0
# Date                    0
# Month                   0
# Status                  0
# Channel                 0
# SKU                     0
# Category                0
# Size                    0
# Qty                     0
# currency                0
# Amount                  0
# ship-city               0
# ship-state              0
# ship-postal-code        0
# ship-country            0
# B2B                 30861
# dtype: int64

# %%
data.notnull().sum()
# Out:
# index               31047
# Order ID            31047
# Cust ID             31047
# Gender              31047
# Age                 31047
# Age Group           31047
# Date                31047
# Month               31047
# Status              31047
# Channel             31047
# SKU                 31047
# Category            31047
# Size                31047
# Qty                 31047
# currency            31047
# Amount              31047
# ship-city           31047
# ship-state          31047
# ship-postal-code    31047
# ship-country        31047
# B2B                   186
# dtype: int64

# %%
#data=data.dropna(subset=['B2B'])
#data.head()
data.notnull().sum()
# Out:
# index               186
# Order ID            186
# Cust ID             186
# Gender              186
# Age                 186
# Age Group           186
# Date                186
# Month               186
# Status              186
# Channel             186
# SKU                 186
# Category            186
# Size                186
# Qty                 186
# currency            186
# Amount              186
# ship-city           186
# ship-state          186
# ship-postal-code    186
# ship-country        186
# B2B                 186
# dtype: int64

# %% [markdown]
# Q5 Rename the column name "Status" to "Status of the Product"

# %%
data.rename( columns = {'Status' : 'Status of the Product'})
# Out:
#        index             Order ID  Cust ID Gender  Age Age Group       Date  \
# 254      255  171-5827792-5989157  5827792  Women   18  Teenager  12/4/2022
# 332      333  407-2239856-6606703  2239856  Women   42     Adult  12/4/2022
# 488      489  402-1412370-9685169  1412370  Women   32     Adult  12/4/2022
# 542      543  403-1973643-5554719  1973643  Women   20  Teenager  12/4/2022
# 738      739  407-9856168-8177132  9856168  Women   35     Adult  12/4/2022
# ...      ...                  ...      ...    ...  ...       ...        ...
# 29714  29715  405-0028632-1550719    28632  Women   64    Senior   2/6/2022
# 29807  29808  407-0962583-9321149   962583  Women   42     Adult   2/6/2022
# 29839  29840  407-4965973-6698749  4965973    Men   22  Teenager   2/6/2022
# 30394  30395  171-2503346-4754748  2503346    Men   29  Teenager   1/6/2022
# 30854  30855  405-4945057-9376333  4945057  Women   32     Adult   1/6/2022
#
# ...

# %% [markdown]
# Q6 what is the mean

# %%
data.Age.mean()
# Out:
# 38.18279569892473

# %% [markdown]
# Q7 what is standars deviation of "pressure" in this data

# %%
data.Age.std()
# Out:
# 14.52338002246565

# %% [markdown]
# Q8 Whats is the Variance of Amount in this data?

# %%
data['Age'].var()
# Out:
# 210.92856727695437

# %% [markdown]
# Q9 Find all instance when "Delivered" was recorded

# %%
data['Status'].value_counts()
# Out:
# Status
# Delivered    177
# Cancelled      4
# Refunded       3
# Returned       2
# Name: count, dtype: int64

# %%
#filtering
data[data['Status'] == 'Delivered']
# Out:
#        index             Order ID  Cust ID Gender  Age Age Group       Date  \
# 254      255  171-5827792-5989157  5827792  Women   18  Teenager  12/4/2022
# 488      489  402-1412370-9685169  1412370  Women   32     Adult  12/4/2022
# 542      543  403-1973643-5554719  1973643  Women   20  Teenager  12/4/2022
# 738      739  407-9856168-8177132  9856168  Women   35     Adult  12/4/2022
# 781      782  406-4969411-1737120  4969411    Men   37     Adult  12/4/2022
# ...      ...                  ...      ...    ...  ...       ...        ...
# 29714  29715  405-0028632-1550719    28632  Women   64    Senior   2/6/2022
# 29807  29808  407-0962583-9321149   962583  Women   42     Adult   2/6/2022
# 29839  29840  407-4965973-6698749  4965973    Men   22  Teenager   2/6/2022
# 30394  30395  171-2503346-4754748  2503346    Men   29  Teenager   1/6/2022
# 30854  30855  405-4945057-9376333  4945057  Women   32     Adult   1/6/2022
#
# ...

# %%
data[data['Status'].str.contains('Delivered')].tail(500)
# Out:
#        index             Order ID  Cust ID Gender  Age Age Group       Date  \
# 254      255  171-5827792-5989157  5827792  Women   18  Teenager  12/4/2022
# 488      489  402-1412370-9685169  1412370  Women   32     Adult  12/4/2022
# 542      543  403-1973643-5554719  1973643  Women   20  Teenager  12/4/2022
# 738      739  407-9856168-8177132  9856168  Women   35     Adult  12/4/2022
# 781      782  406-4969411-1737120  4969411    Men   37     Adult  12/4/2022
# ...      ...                  ...      ...    ...  ...       ...        ...
# 29714  29715  405-0028632-1550719    28632  Women   64    Senior   2/6/2022
# 29807  29808  407-0962583-9321149   962583  Women   42     Adult   2/6/2022
# 29839  29840  407-4965973-6698749  4965973    Men   22  Teenager   2/6/2022
# 30394  30395  171-2503346-4754748  2503346    Men   29  Teenager   1/6/2022
# 30854  30855  405-4945057-9376333  4945057  Women   32     Adult   1/6/2022
#
# ...

# %% [markdown]
# Q10 Find all instances when 'age is above 30' and 'category is saree'

# %%
data[(data['Age']>30 )  & (data['Category']=='Saree')]
# Out:
#        index             Order ID  Cust ID Gender  Age Age Group       Date  \
# 488      489  402-1412370-9685169  1412370  Women   32     Adult  12/4/2022
# 2113    2114  404-5901963-7277154  5901963  Women   32     Adult  10/4/2022
# 7251    7252  406-3172615-1008326  3172615  Women   59    Senior   4/4/2022
# 11132  11133  408-3542694-7939522  3542694    Men   47     Adult  12/5/2022
#
#       Month     Status Channel   ... Category  Size Qty  currency Amount  \
# 488     Dec  Delivered   Amazon  ...    Saree  Free   1       INR    958
# 2113    Oct  Delivered   Amazon  ...    Saree  Free   1       INR    832
# 7251    Apr  Delivered     Ajio  ...    Saree  Free   1       INR    487
# 11132   Dec  Delivered   Others  ...    Saree  Free   2       INR    736
#
#          ship-city   ship-state ship-postal-code  ship-country  B2B
# 488       Rasayani  MAHARASHTRA           410222            IN  1.0
# 2113     BENGALURU    KARNATAKA           560029            IN  1.0
# ...

# %% [markdown]
# Q11 Whats is the Mean value of each Column against each "Amount"

# %% [markdown]
# Q12 What is the min and max value of each column against each

# %%
data.groupby('Amount').min()
# Out:
#         index             Order ID  Cust ID Gender  Age Age Group       Date  \
# Amount
# 267     14813  402-5419864-6450728  5419864  Women   23  Teenager   7/5/2022
# 277     10401  405-9719537-1306727  9719537  Women   48     Adult   1/4/2022
# 292      4782  402-9226250-2259547  6942210  Women   33     Adult   7/4/2022
# 301     26973  403-7250923-3661949  7250923  Women   38     Adult   6/6/2022
# 308     18850  403-3739970-4627526  3739970  Women   74    Senior   3/5/2022
# ...       ...                  ...      ...    ...  ...       ...        ...
# 1338    15063  171-6299664-9769158  4477910    Men   29     Adult   1/5/2022
# 1354    13158  404-9434151-7260300  9434151    Men   26  Teenager   9/5/2022
# 1369    20735  171-3085849-1909954  3085849    Men   44     Adult   1/5/2022
# 1442    27174  407-5024299-2737954  5024299  Women   33     Adult   6/6/2022
# 1523    12131  404-2013002-4312352  2013002    Men   35     Adult  11/5/2022
#
# ...

# %%
data.groupby('Amount').max()
# Out:
#         index             Order ID  Cust ID Gender  Age Age Group       Date  \
# Amount
# 267     14813  402-5419864-6450728  5419864  Women   23  Teenager   7/5/2022
# 277     10401  405-9719537-1306727  9719537  Women   48     Adult   1/4/2022
# 292     24995  403-6942210-8530739  9226250  Women   54    Senior   8/6/2022
# 301     26973  403-7250923-3661949  7250923  Women   38     Adult   6/6/2022
# 308     18850  403-3739970-4627526  3739970  Women   74    Senior   3/5/2022
# ...       ...                  ...      ...    ...  ...       ...        ...
# 1338    21155  408-4477910-2985917  8687574  Women   40  Teenager   7/5/2022
# 1354    13158  404-9434151-7260300  9434151    Men   26  Teenager   9/5/2022
# 1369    20735  171-3085849-1909954  3085849    Men   44     Adult   1/5/2022
# 1442    27174  407-5024299-2737954  5024299  Women   33     Adult   6/6/2022
# 1523    12131  404-2013002-4312352  2013002    Men   35     Adult  11/5/2022
#
# ...

# %% [markdown]
# Q13 Show all the Records where category="Saree"

# %%
data[data['Category'] == 'Saree']
# Out:
#        index             Order ID  Cust ID Gender  Age Age Group       Date  \
# 488      489  402-1412370-9685169  1412370  Women   32     Adult  12/4/2022
# 2113    2114  404-5901963-7277154  5901963  Women   32     Adult  10/4/2022
# 7251    7252  406-3172615-1008326  3172615  Women   59    Senior   4/4/2022
# 11132  11133  408-3542694-7939522  3542694    Men   47     Adult  12/5/2022
#
#       Month     Status Channel   ... Category  Size Qty  currency Amount  \
# 488     Dec  Delivered   Amazon  ...    Saree  Free   1       INR    958
# 2113    Oct  Delivered   Amazon  ...    Saree  Free   1       INR    832
# 7251    Apr  Delivered     Ajio  ...    Saree  Free   1       INR    487
# 11132   Dec  Delivered   Others  ...    Saree  Free   2       INR    736
#
#          ship-city   ship-state ship-postal-code  ship-country  B2B
# 488       Rasayani  MAHARASHTRA           410222            IN  1.0
# 2113     BENGALURU    KARNATAKA           560029            IN  1.0
# ...

# %% [markdown]
# Q14 Find all instance when

# %%
data[(data['Category'] == 'kurta')   |  (data['Age']>30)]
# Out:
#        index             Order ID  Cust ID Gender  Age Age Group       Date  \
# 332      333  407-2239856-6606703  2239856  Women   42     Adult  12/4/2022
# 488      489  402-1412370-9685169  1412370  Women   32     Adult  12/4/2022
# 738      739  407-9856168-8177132  9856168  Women   35     Adult  12/4/2022
# 781      782  406-4969411-1737120  4969411    Men   37     Adult  12/4/2022
# 940      941  403-6194318-0886738  6194318  Women   39     Adult  11/4/2022
# ...      ...                  ...      ...    ...  ...       ...        ...
# 28922  28923  402-4906965-2174762  4906965    Men   33     Adult   3/6/2022
# 29129  29130  402-8473478-5082719  8473478  Women   49     Adult   3/6/2022
# 29714  29715  405-0028632-1550719    28632  Women   64    Senior   2/6/2022
# 29807  29808  407-0962583-9321149   962583  Women   42     Adult   2/6/2022
# 30854  30855  405-4945057-9376333  4945057  Women   32     Adult   1/6/2022
#
# ...

# %%
Q15 find all instance

# %%
data[(data['Category']== 'Kurta') & (data['Month'] =='Dec')   | (data['Gender']=='Women')]
# Out:
#        index             Order ID  Cust ID Gender  Age Age Group       Date  \
# 254      255  171-5827792-5989157  5827792  Women   18  Teenager  12/4/2022
# 332      333  407-2239856-6606703  2239856  Women   42     Adult  12/4/2022
# 488      489  402-1412370-9685169  1412370  Women   32     Adult  12/4/2022
# 542      543  403-1973643-5554719  1973643  Women   20  Teenager  12/4/2022
# 738      739  407-9856168-8177132  9856168  Women   35     Adult  12/4/2022
# ...      ...                  ...      ...    ...  ...       ...        ...
# 28912  28913  406-8327448-0319538  8327448  Women   53    Senior   3/6/2022
# 29129  29130  402-8473478-5082719  8473478  Women   49     Adult   3/6/2022
# 29714  29715  405-0028632-1550719    28632  Women   64    Senior   2/6/2022
# 29807  29808  407-0962583-9321149   962583  Women   42     Adult   2/6/2022
# 30854  30855  405-4945057-9376333  4945057  Women   32     Adult   1/6/2022
#
# ...
